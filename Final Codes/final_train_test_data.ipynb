# %%
import pandas as pd
import numpy as np

# %%
############################  TEST #######################################################

genuine = pd.read_csv(r"G:\Signature Verification Project\data\Final Data\Testing\genuine_test.csv")


gen_forg = pd.read_csv(r"G:\Signature Verification Project\data\Final Data\Testing\gen_forg_test.csv")

genuine = genuine.fillna(0)
gen_forg = gen_forg.fillna(0)

genuine = genuine.groupby('ID').agg(lambda x: list(x)).reset_index()

gen_forg = gen_forg.groupby('ID').agg(lambda x: list(x)).reset_index()




ids = []

for i in gen_forg["ID"]:
    ids.append(i)
    
    
new_id = []

for i in ids:
    new_i = i.replace("test\\", "")
    new_id.append(new_i)
    
gen_forg["ID"] = new_id





genuine['g_key'] = genuine['ID'].str[:3]
gen_forg['fg_key'] = gen_forg['ID'].str[:3]


dicti = {"ID":"g_ID",
         "X":"g_X",
         "Y":"g_Y",
         'R':"g_R", 'Angle':"g_Angle", 'del_x':"g_del_x", 'del_y':"g_del_y",
       'displacement':"g_displacement", 'disp_angle':"g_disp_angle", 'cos_angle':"g_cos_angle", 'sine_angle':"g_sine_angle", 
         'vel_x':"g_vel_x", 'vel_y':"g_vel_y", 'res_vel':"g_res_vel", 'dir_res_vel':"g_dir_res_vel", 'angular_vel':"g_angular_vel", 
         'acceleration_x':"g_acceleration_x",
       'acceleration_y':"g_acceleration_y", 'res_acceleration':"g_res_acceleration", 'centripetal_accln':"g_centripetal_accln",
       'tangential_accln':"g_tangential_accln"}

genuine.rename(columns = dicti, inplace = True)



dicti_fg = {"ID":"fg_ID",
         "X":"fg_X",
         "Y":"fg_Y",
         'R':"fg_R", 'Angle':"fg_Angle", 'del_x':"fg_del_x", 'del_y':"fg_del_y",
       'displacement':"fg_displacement", 'disp_angle':"fg_disp_angle", 'cos_angle':"fg_cos_angle", 'sine_angle':"fg_sine_angle", 
         'vel_x':"fg_vel_x", 'vel_y':"fg_vel_y", 'res_vel':"fg_res_vel", 'dir_res_vel':"fg_dir_res_vel", 'angular_vel':"fg_angular_vel", 
         'acceleration_x':"fg_acceleration_x",
       'acceleration_y':"fg_acceleration_y", 'res_acceleration':"fg_res_acceleration", 'centripetal_accln':"fg_centripetal_accln",
       'tangential_accln':"fg_tangential_accln"}

gen_forg.rename(columns = dicti_fg, inplace = True)

genuine.rename(columns = {"g_key": "key"}, inplace = True)
gen_forg.rename(columns = {"fg_key": "key"}, inplace = True)

result = pd.merge(genuine, gen_forg, on ='key').drop("key", 1)

test_data = pd.read_csv(r"G:\Signature Verification Project\data\test_data.csv")

result["g_ID"][:2], result["fg_ID"][:2]

result["new_key"] = result[["g_ID", "fg_ID"]].apply(lambda x: "_".join(x), axis = 1)
test_data["new_key"] = test_data[["ID", "opposite_image"]].apply(lambda x: "_".join(x), axis = 1)

result["new_key"].head(), test_data["new_key"].head()

final_test = result.merge(test_data, how = "left", left_on = "new_key", right_on = "new_key")

final_test = final_test.drop(["new_key", "ID", "opposite_image"], axis = 1)



final_test["fg_X"] = final_test["fg_X"].apply(lambda a:round(np.mean(a), 1))
final_test["fg_Y"] = final_test["fg_Y"].apply(lambda a:round(np.mean(a), 1))
final_test["fg_R"] = final_test["fg_R"].apply(lambda a:round(np.mean(a), 1))
final_test["fg_Angle"] = final_test["fg_Angle"].apply(lambda a:round(np.mean(a), 1))
final_test["fg_del_x"] = final_test["fg_del_x"].apply(lambda a:round(np.mean(a), 1))
final_test["fg_del_y"] = final_test["fg_del_y"].apply(lambda a:round(np.mean(a), 1))
final_test["fg_displacement"] = final_test["fg_displacement"].apply(lambda a:round(np.mean(a), 1))
final_test["fg_disp_angle"] = final_test["fg_disp_angle"].apply(lambda a:round(np.mean(a), 1))
final_test["fg_cos_angle"] = final_test["fg_cos_angle"].apply(lambda a:round(np.mean(a), 1))
final_test["fg_sine_angle"] = final_test["fg_sine_angle"].apply(lambda a:round(np.mean(a), 1))
final_test["fg_vel_x"] = final_test["fg_vel_x"].apply(lambda a:round(np.mean(a), 1))
final_test["fg_vel_y"] = final_test["fg_vel_y"].apply(lambda a:round(np.mean(a), 1))
final_test["fg_res_vel"] = final_test["fg_res_vel"].apply(lambda a:round(np.mean(a), 1))
final_test["fg_dir_res_vel"] = final_test["fg_dir_res_vel"].apply(lambda a:round(np.mean(a), 1))
final_test["fg_angular_vel"] = final_test["fg_angular_vel"].apply(lambda a:round(np.mean(a), 1))
final_test["fg_acceleration_x"] = final_test["fg_acceleration_x"].apply(lambda a:round(np.mean(a), 1))
final_test["fg_acceleration_y"] = final_test["fg_acceleration_y"].apply(lambda a:round(np.mean(a), 1))
final_test["fg_res_acceleration"] = final_test["fg_res_acceleration"].apply(lambda a:round(np.mean(a), 1))
final_test["fg_centripetal_accln"] = final_test["fg_centripetal_accln"].apply(lambda a:round(np.mean(a), 1))
final_test["fg_tangential_accln"] = final_test["fg_tangential_accln"].apply(lambda a:round(np.mean(a), 1))

final_test["g_X"] = final_test["g_X"].apply(lambda a:round(np.mean(a), 1))
final_test["g_Y"] = final_test["g_Y"].apply(lambda a:round(np.mean(a), 1))
final_test["g_R"] = final_test["g_R"].apply(lambda a:round(np.mean(a), 1))
final_test["g_Angle"] = final_test["g_Angle"].apply(lambda a:round(np.mean(a), 1))
final_test["g_del_x"] = final_test["g_del_x"].apply(lambda a:round(np.mean(a), 1))
final_test["g_del_y"] = final_test["g_del_y"].apply(lambda a:round(np.mean(a), 1))
final_test["g_displacement"] = final_test["g_displacement"].apply(lambda a:round(np.mean(a), 1))
final_test["g_disp_angle"] = final_test["g_disp_angle"].apply(lambda a:round(np.mean(a), 1))
final_test["g_cos_angle"] = final_test["g_cos_angle"].apply(lambda a:round(np.mean(a), 1))
final_test["g_sine_angle"] = final_test["g_sine_angle"].apply(lambda a:round(np.mean(a), 1))
final_test["g_vel_x"] = final_test["g_vel_x"].apply(lambda a:round(np.mean(a), 1))
final_test["g_vel_y"] = final_test["g_vel_y"].apply(lambda a:round(np.mean(a), 1))
final_test["g_res_vel"] = final_test["g_res_vel"].apply(lambda a:round(np.mean(a), 1))
final_test["g_dir_res_vel"] = final_test["g_dir_res_vel"].apply(lambda a:round(np.mean(a), 1))
final_test["g_angular_vel"] = final_test["g_angular_vel"].apply(lambda a:round(np.mean(a), 1))
final_test["g_acceleration_x"] = final_test["g_acceleration_x"].apply(lambda a:round(np.mean(a), 1))
final_test["g_acceleration_y"] = final_test["g_acceleration_y"].apply(lambda a:round(np.mean(a), 1))
final_test["g_res_acceleration"] = final_test["g_res_acceleration"].apply(lambda a:round(np.mean(a), 1))
final_test["g_centripetal_accln"] = final_test["g_centripetal_accln"].apply(lambda a:round(np.mean(a), 1))
final_test["g_tangential_accln"] = final_test["g_tangential_accln"].apply(lambda a:round(np.mean(a), 1))


final_test = final_test[pd.notnull(final_test["f_g"])]

final_test.to_csv(r"G:\Signature Verification Project\data\Final Data\final_test.csv", index = False)


print("complete test")

#print(final_test.head())
print(final_test.shape)

del genuine, gen_forg, dicti, dicti_fg, result, test_data

# %%
############################  Train  #######################################################


genuine = pd.read_csv(r"G:\Signature Verification Project\data\Final Data\Training\genuine_train.csv")


gen_forg = pd.read_csv(r"G:\Signature Verification Project\data\Final Data\Training\gen_forg_train.csv")

genuine = genuine.fillna(0)
gen_forg = gen_forg.fillna(0)


genuine = genuine.groupby('ID').agg(lambda x: list(x)).reset_index()

gen_forg = gen_forg.groupby('ID').agg(lambda x: list(x)).reset_index()





ids = []

for i in gen_forg["ID"]:
    ids.append(i)
    
    
new_id = []

for i in ids:
    new_i = i.replace("rain\\", "")
    new_id.append(new_i)
    
gen_forg["ID"] = new_id





genuine['g_key'] = genuine['ID'].str[:3]
gen_forg['fg_key'] = gen_forg['ID'].str[:3]


dicti = {"ID":"g_ID",
         "X":"g_X",
         "Y":"g_Y",
         'R':"g_R", 'Angle':"g_Angle", 'del_x':"g_del_x", 'del_y':"g_del_y",
       'displacement':"g_displacement", 'disp_angle':"g_disp_angle", 'cos_angle':"g_cos_angle", 'sine_angle':"g_sine_angle", 
         'vel_x':"g_vel_x", 'vel_y':"g_vel_y", 'res_vel':"g_res_vel", 'dir_res_vel':"g_dir_res_vel", 'angular_vel':"g_angular_vel", 
         'acceleration_x':"g_acceleration_x",
       'acceleration_y':"g_acceleration_y", 'res_acceleration':"g_res_acceleration", 'centripetal_accln':"g_centripetal_accln",
       'tangential_accln':"g_tangential_accln"}

genuine.rename(columns = dicti, inplace = True)



dicti_fg = {"ID":"fg_ID",
         "X":"fg_X",
         "Y":"fg_Y",
         'R':"fg_R", 'Angle':"fg_Angle", 'del_x':"fg_del_x", 'del_y':"fg_del_y",
       'displacement':"fg_displacement", 'disp_angle':"fg_disp_angle", 'cos_angle':"fg_cos_angle", 'sine_angle':"fg_sine_angle", 
         'vel_x':"fg_vel_x", 'vel_y':"fg_vel_y", 'res_vel':"fg_res_vel", 'dir_res_vel':"fg_dir_res_vel", 'angular_vel':"fg_angular_vel", 
         'acceleration_x':"fg_acceleration_x",
       'acceleration_y':"fg_acceleration_y", 'res_acceleration':"fg_res_acceleration", 'centripetal_accln':"fg_centripetal_accln",
       'tangential_accln':"fg_tangential_accln"}

gen_forg.rename(columns = dicti_fg, inplace = True)

genuine.rename(columns = {"g_key": "key"}, inplace = True)
gen_forg.rename(columns = {"fg_key": "key"}, inplace = True)

result = pd.merge(genuine, gen_forg, on ='key').drop("key", 1)

train_data = pd.read_csv(r"G:\Signature Verification Project\data\train_data.csv")

result["g_ID"][:2], result["fg_ID"][:2]

result["new_key"] = result[["g_ID", "fg_ID"]].apply(lambda x: "_".join(x), axis = 1)
train_data["new_key"] = train_data[["ID", "opposite_image"]].apply(lambda x: "_".join(x), axis = 1)

result["new_key"].head(), train_data["new_key"].head()

final_train = result.merge(train_data, how = "left", left_on = "new_key", right_on = "new_key")

final_train = final_train.drop(["new_key", "ID", "opposite_image"], axis = 1)



final_train["fg_X"] = final_train["fg_X"].apply(lambda a:round(np.mean(a), 1))
final_train["fg_Y"] = final_train["fg_Y"].apply(lambda a:round(np.mean(a), 1))
final_train["fg_R"] = final_train["fg_R"].apply(lambda a:round(np.mean(a), 1))
final_train["fg_Angle"] = final_train["fg_Angle"].apply(lambda a:round(np.mean(a), 1))
final_train["fg_del_x"] = final_train["fg_del_x"].apply(lambda a:round(np.mean(a), 1))
final_train["fg_del_y"] = final_train["fg_del_y"].apply(lambda a:round(np.mean(a), 1))
final_train["fg_displacement"] = final_train["fg_displacement"].apply(lambda a:round(np.mean(a), 1))
final_train["fg_disp_angle"] = final_train["fg_disp_angle"].apply(lambda a:round(np.mean(a), 1))
final_train["fg_cos_angle"] = final_train["fg_cos_angle"].apply(lambda a:round(np.mean(a), 1))
final_train["fg_sine_angle"] = final_train["fg_sine_angle"].apply(lambda a:round(np.mean(a), 1))
final_train["fg_vel_x"] = final_train["fg_vel_x"].apply(lambda a:round(np.mean(a), 1))
final_train["fg_vel_y"] = final_train["fg_vel_y"].apply(lambda a:round(np.mean(a), 1))
final_train["fg_res_vel"] = final_train["fg_res_vel"].apply(lambda a:round(np.mean(a), 1))
final_train["fg_dir_res_vel"] = final_train["fg_dir_res_vel"].apply(lambda a:round(np.mean(a), 1))
final_train["fg_angular_vel"] = final_train["fg_angular_vel"].apply(lambda a:round(np.mean(a), 1))
final_train["fg_acceleration_x"] = final_train["fg_acceleration_x"].apply(lambda a:round(np.mean(a), 1))
final_train["fg_acceleration_y"] = final_train["fg_acceleration_y"].apply(lambda a:round(np.mean(a), 1))
final_train["fg_res_acceleration"] = final_train["fg_res_acceleration"].apply(lambda a:round(np.mean(a), 1))
final_train["fg_centripetal_accln"] = final_train["fg_centripetal_accln"].apply(lambda a:round(np.mean(a), 1))
final_train["fg_tangential_accln"] = final_train["fg_tangential_accln"].apply(lambda a:round(np.mean(a), 1))

final_train["g_X"] = final_train["g_X"].apply(lambda a:round(np.mean(a), 1))
final_train["g_Y"] = final_train["g_Y"].apply(lambda a:round(np.mean(a), 1))
final_train["g_R"] = final_train["g_R"].apply(lambda a:round(np.mean(a), 1))
final_train["g_Angle"] = final_train["g_Angle"].apply(lambda a:round(np.mean(a), 1))
final_train["g_del_x"] = final_train["g_del_x"].apply(lambda a:round(np.mean(a), 1))
final_train["g_del_y"] = final_train["g_del_y"].apply(lambda a:round(np.mean(a), 1))
final_train["g_displacement"] = final_train["g_displacement"].apply(lambda a:round(np.mean(a), 1))
final_train["g_disp_angle"] = final_train["g_disp_angle"].apply(lambda a:round(np.mean(a), 1))
final_train["g_cos_angle"] = final_train["g_cos_angle"].apply(lambda a:round(np.mean(a), 1))
final_train["g_sine_angle"] = final_train["g_sine_angle"].apply(lambda a:round(np.mean(a), 1))
final_train["g_vel_x"] = final_train["g_vel_x"].apply(lambda a:round(np.mean(a), 1))
final_train["g_vel_y"] = final_train["g_vel_y"].apply(lambda a:round(np.mean(a), 1))
final_train["g_res_vel"] = final_train["g_res_vel"].apply(lambda a:round(np.mean(a), 1))
final_train["g_dir_res_vel"] = final_train["g_dir_res_vel"].apply(lambda a:round(np.mean(a), 1))
final_train["g_angular_vel"] = final_train["g_angular_vel"].apply(lambda a:round(np.mean(a), 1))
final_train["g_acceleration_x"] = final_train["g_acceleration_x"].apply(lambda a:round(np.mean(a), 1))
final_train["g_acceleration_y"] = final_train["g_acceleration_y"].apply(lambda a:round(np.mean(a), 1))
final_train["g_res_acceleration"] = final_train["g_res_acceleration"].apply(lambda a:round(np.mean(a), 1))
final_train["g_centripetal_accln"] = final_train["g_centripetal_accln"].apply(lambda a:round(np.mean(a), 1))
final_train["g_tangential_accln"] = final_train["g_tangential_accln"].apply(lambda a:round(np.mean(a), 1))


final_train = final_train[pd.notnull(final_train["f_g"])]


final_train.to_csv(r"G:\Signature Verification Project\data\Final Data\final_train.csv", index = False)



print("complete train")

#print(final_train.head())
print(final_train.shape)

del genuine, gen_forg, dicti, dicti_fg, result, train_data
# Out:
# complete train
# (17458, 43)

# %%
gen_forg = pd.read_csv(r"G:\Signature Verification Project\data\Final Data\Training\gen_forg_train.csv")

gen_forg = gen_forg.fillna(0)


gen_forg = gen_forg.groupby('ID').agg(lambda x: list(x)).reset_index()

# %%
gen_forg["fg_key"][:20]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-d15eed4aed8d> in <module>
# ----> 1 gen_forg["fg_key"][:20]
#
# NameError: name 'gen_forg' is not defined
